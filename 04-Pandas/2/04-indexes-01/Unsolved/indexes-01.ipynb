# %% [markdown]
# # Slice and Dice Pandas DataFrames via Indexes

# %% [markdown]
# ## 1. Import libraries and dependencies

# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## 2. Create a Path to the File Using Pathlib

# %%
# Use the Pathlib libary to set the path to the CSV
csv_path = Path('../Resources/cleaned_people_data.csv')

# %% [markdown]
# ## 3. Read the CSV into a Pandas DataFrame

# %%
# Read in the CSV as a DataFrame
people_csv = pd.read_csv(csv_path)
people_csv.head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0          1    Lenormand    Keriann  Female
# 1          2        Rupke    Huntley    Male
# 2          3  Dalgarnowch     Gorden    Male
# 3          4      Unnamed     Cullie    Male
# 4          5    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# 2  59196.0      gdalgarnowch2@microsoft.com   40
# 3  88493.0               cputten3@nymag.com   62
# 4  89073.0       astrangman4@bravesites.com   47

# %% [markdown]
# ## 4. Index Selection with iloc

# %% [markdown]
# ### 1. Select First Row with iloc

# %%
# Select the first row of the DataFrame
people_csv.iloc[0]
# Out:
# Person_ID                                   1
# Last_Name                           Lenormand
# First_Name                            Keriann
# Gender                                 Female
# University                  Aurora University
# Occupation                 Nurse Practicioner
# Salary                                58135.0
# Email         klenormand0@businessinsider.com
# Age                                        27
# Name: 0, dtype: object

# %% [markdown]
# ### 2. Select First 10 Rows Using Index Selection with iloc

# %%
# Select the first 10 rows of the DataFrame
people_csv.iloc[:10]
# Out:
#    Person_ID    Last_Name  First_Name  Gender  \
# 0          1    Lenormand     Keriann  Female
# 1          2        Rupke     Huntley    Male
# 2          3  Dalgarnowch      Gorden    Male
# 3          4      Unnamed      Cullie    Male
# 4          5    Strangman       Ariel  Female
# 5          6    Snozzwell     Antonio    Male
# 6          7     Neathway       Darya  Female
# 7          8       Duding     Helaina  Female
# 8          9   Franzolini  Gerhardine  Female
# 9         10        Traut       Charo  Female
#
#                                           University  \
# 0                                  Aurora University
# 1                      Osaka University of Economics
# 2                                  Ludong University
# 3  Université des Sciences et de la Technologie d...
# 4                             Boise State University
# 5                                 Babcock University
# 6                                     Molloy College
# 7                                St. Paul University
# 8                  Fundação Educacional de Ituverava
# 9                                 Cornell University
#
#                  Occupation    Salary                            Email  Age
# 0        Nurse Practicioner   58135.0  klenormand0@businessinsider.com   27
# 1           Project Manager   96053.0              hrupke1@reuters.com   22
# 2        Environmental Tech   59196.0      gdalgarnowch2@microsoft.com   40
# 3           Legal Assistant   88493.0               cputten3@nymag.com   62
# 4           Project Manager   89073.0       astrangman4@bravesites.com   47
# 5          Technical Writer  119916.0            asnozzwell5@mysql.com   49
# 6    Administrative Officer   77705.0            dneathway6@seesaa.net   64
# 7           Staff Scientist   57166.0               hduding7@topsy.com   26
# 8  Environmental Specialist   73051.0             gfranzolini8@msn.com   22
# 9            Programmer III   90631.0               ctraut9@oracle.com   45

# %% [markdown]
# ### 3. Select Last Row Using Index Selection with iloc

# %%
# Select the last row of the DataFrame
people_csv.iloc[2]
# Out:
# Person_ID                               3
# Last_Name                     Dalgarnowch
# First_Name                         Gorden
# Gender                               Male
# University              Ludong University
# Occupation             Environmental Tech
# Salary                            59196.0
# Email         gdalgarnowch2@microsoft.com
# Age                                    40
# Name: 2, dtype: object

# %% [markdown]
# ### 4. Select Second Column Using Index Selection with iloc

# %%
# Select the second column of the DataFrame
people_csv.iloc[:,1]
# Out:
# 0        Lenormand
# 1            Rupke
# 2      Dalgarnowch
# 3          Unnamed
# 4        Strangman
#           ...
# 968       Crumpton
# 969        Gilford
# 970        Gurling
# 971           Yang
# 972           Yang
# Name: Last_Name, Length: 973, dtype: object

# %% [markdown]
# ### 5. Select Last Column Using Index Selection with iloc

# %%
# Select the last column of the DataFrame, with all rows
people_csv.iloc[:, -1]
# Out:
# 0      27
# 1      22
# 2      40
# 3      62
# 4      47
#        ..
# 968    52
# 969    32
# 970    48
# 971    53
# 972    53
# Name: Age, Length: 973, dtype: int64

# %% [markdown]
# ### 6. Select First Three Columns Using Index Selection with iloc

# %%
# Select the first three columns of the DataFrame, with all rows
people_csv.iloc[:, :3]
# Out:
#      Person_ID    Last_Name First_Name
# 0            1    Lenormand    Keriann
# 1            2        Rupke    Huntley
# 2            3  Dalgarnowch     Gorden
# 3            4      Unnamed     Cullie
# 4            5    Strangman      Ariel
# ..         ...          ...        ...
# 968        996     Crumpton       Meta
# 969        997      Gilford      Gunar
# 970        998      Gurling   Lucretia
# 971        999         Yang     Andrew
# 972        999         Yang     Andrew
#
# [973 rows x 3 columns]

# %% [markdown]
# ### 7. Select Specific Rows and Columns Using Index Selection with iloc

# %%
# Select the 1st, 3th, 5th, 7th rows of the 2nd, 4th, and 6th columns.
people_csv.iloc[[0,2,4,6],[1,3,5]]
# Out:
#      Last_Name  Gender              Occupation
# 0    Lenormand  Female      Nurse Practicioner
# 2  Dalgarnowch    Male      Environmental Tech
# 4    Strangman  Female         Project Manager
# 6     Neathway  Female  Administrative Officer

# %% [markdown]
# ### 8. Select Ranges of Rows and Columns Using Index Selection with iloc

# %%
# Select the first 5 rows of the 3rd, 4th, and 5th columns of the DataFrame
people_csv.iloc[:5, [2,3,4]]
# Out:
#   First_Name  Gender                                         University
# 0    Keriann  Female                                  Aurora University
# 1    Huntley    Male                      Osaka University of Economics
# 2     Gorden    Male                                  Ludong University
# 3     Cullie    Male  Université des Sciences et de la Technologie d...
# 4      Ariel  Female                             Boise State University

# %% [markdown]
# ### 9. Assign Values to Specific Rows and Columns Using Index Assignment with iLoc

# %%
# Modify the 'first_name' column value of the first row
people_csv.iloc[1, people_csv.columns.get_loc('Last_Name')]
# Out:
# 'Rupke'

# %% [markdown]
# ## 5. Index Selection with `loc`:

# %% [markdown]
# ### 1. Set Column as Pandas DataFrame Index

# %%
# Set the index as the 'First_Name' column
people_csv.set_index(people_csv["First_Name"], inplace = True)
people_csv
# Out:
#             Person_ID    Last_Name First_Name  Gender  \
# First_Name
# Keriann             1    Lenormand    Keriann  Female
# Huntley             2        Rupke    Huntley    Male
# Gorden              3  Dalgarnowch     Gorden    Male
# Cullie              4      Unnamed     Cullie    Male
# Ariel               5    Strangman      Ariel  Female
# ...               ...          ...        ...     ...
# Meta              996     Crumpton       Meta  Female
# Gunar             997      Gilford      Gunar    Male
# Lucretia          998      Gurling   Lucretia  Female
# Andrew            999         Yang     Andrew    Male
# Andrew            999         Yang     Andrew    Male
#
#                                                    University  \
# First_Name
# Keriann                                     Aurora University
# Huntley                         Osaka University of Economics
# Gorden                                      Ludong University
# Cullie      Université des Sciences et de la Technologie d...
# Ariel                                  Boise State University
# ...                                                       ...
# Meta                     ECAM - Institut Supérieur Industriel
# Gunar                                       Smolny University
# Lucretia                            Institut Teknologi Telkom
# Andrew                  Rutgers University School of Business
# Andrew                  Rutgers University School of Business
#
#                        Occupation   Salary                            Email  \
# First_Name
# Keriann        Nurse Practicioner  58135.0  klenormand0@businessinsider.com
# Huntley           Project Manager  96053.0              hrupke1@reuters.com
# Gorden         Environmental Tech  59196.0      gdalgarnowch2@microsoft.com
# Cullie            Legal Assistant  88493.0               cputten3@nymag.com
# Ariel             Project Manager  89073.0       astrangman4@bravesites.com
# ...                           ...      ...                              ...
# Meta             Registered Nurse  57060.0               mcrumptonrn@qq.com
# Gunar           Marketing Manager  76109.0             ggilfordro@yandex.ru
# Lucretia    Software Engineer III  92115.0                 lgurlingrp@de.vu
# Andrew        Curriculum Engineer  60000.0             ayang@codedrills.com
# Andrew        Curriculum Engineer  60000.0             ayang@codedrills.com
#
#             Age
# First_Name
# Keriann      27
# Huntley      22
# Gorden       40
# Cullie       62
# Ariel        47
# ...         ...
# Meta         52
# Gunar        32
# Lucretia     48
# Andrew       53
# Andrew       53
#
# [973 rows x 9 columns]

# %% [markdown]
# ### 2. Sort Pandas DataFrame by Index

# %%
# Sort the index
people_csv.sort_index(inplace=True)
people_csv
# Out:
#             Person_ID      Last_Name First_Name  Gender  \
# First_Name
# Aaron             461       De Brett      Aaron    Male
# Abbot             459      McGaughey      Abbot    Male
# Abbye             125      MacKnight      Abbye  Female
# Abner             158  Christauffour      Abner    Male
# Abra              177         Vawton       Abra  Female
# ...               ...            ...        ...     ...
# Zachariah         825           Akid  Zachariah    Male
# Zandra            816     Kollaschek     Zandra  Female
# Zebulon            58      Josefovic    Zebulon    Male
# Zerk               59       Goulston       Zerk    Male
# Zsazsa             81        Cutajar     Zsazsa  Female
#
#                                                    University  \
# First_Name
# Aaron                                      Tsurumi University
# Abbot                                 University of Mauritius
# Abbye                               Savannah State University
# Abner                         Universidade Federal de Alagoas
# Abra                      Kawasaki University of Medical Care
# ...                                                       ...
# Zachariah                             Kyoto Sangyo University
# Zandra                       Western International University
# Zebulon                               Rajiv Gandhi University
# Zerk                    Universidad Tecnologica de la Mixteca
# Zsazsa      Asia Pacific Institute of Information Technolo...
#
#                               Occupation    Salary  \
# First_Name
# Aaron                  Director of Sales   76098.0
# Abbot                       Food Chemist  105216.0
# Abbye                Account Coordinator   90949.0
# Abner         Account Representative III  102758.0
# Abra                   Financial Advisor   76598.0
# ...                                  ...       ...
# Zachariah             Office Assistant I  111040.0
# Zandra          Senior Financial Analyst  109904.0
# Zebulon              Staff Accountant IV   82462.0
# Zerk        Budget/Accounting Analyst II   71428.0
# Zsazsa       Mechanical Systems Engineer   57814.0
#
#                                        Email  Age
# First_Name
# Aaron             adebrettcs@yellowpages.com   45
# Abbot                  amcgaugheycq@jugem.jp   35
# Abbye       amacknight3g@theglobeandmail.com   42
# Abner             achristauffour4d@tmall.com   47
# Abra                   avawton4w@nbcnews.com   23
# ...                                      ...  ...
# Zachariah                   zakidmw@live.com   47
# Zandra                 zkollaschekmn@home.pl   34
# Zebulon             zjosefovic1l@pcworld.com   63
# Zerk               zgoulston1m@artisteer.com   35
# Zsazsa                     zcutajar28@i2i.jp   27
#
# [973 rows x 9 columns]

# %% [markdown]
# ### 3. Select Specific Row with Index Selection using loc

# %%
# Select the row with the index 'Andrew'
people_csv.loc["Andrew"]
# Out:
#             Person_ID Last_Name First_Name Gender  \
# First_Name
# Andrew            999      Yang     Andrew   Male
# Andrew            999      Yang     Andrew   Male
#
#                                        University           Occupation  \
# First_Name
# Andrew      Rutgers University School of Business  Curriculum Engineer
# Andrew      Rutgers University School of Business  Curriculum Engineer
#
#              Salary                 Email  Age
# First_Name
# Andrew      60000.0  ayang@codedrills.com   53
# Andrew      60000.0  ayang@codedrills.com   53

# %% [markdown]
# ### 4. Select Ranges of Rows with Index Selection using loc

# %%
# Slice the data to output the range of rows between 'Andrew' and 'Vonnie' using `loc`.
people_csv.loc["Andrew":"Vonnie"]
# Out:
#             Person_ID Last_Name First_Name  Gender  \
# First_Name
# Andrew            999      Yang     Andrew    Male
# Andrew            999      Yang     Andrew    Male
# Anett              86    Dellit      Anett  Female
# Angelico          855  Benardet   Angelico    Male
# Angie             984   Maharey      Angie  Female
# ...               ...       ...        ...     ...
# Vincents          956   Ainslee   Vincents    Male
# Virgil             27    Dunnet     Virgil    Male
# Vivi               89    Brandi       Vivi  Female
# Viviyan            40   Halifax    Viviyan  Female
# Vonnie            318  Jindacek     Vonnie  Female
#
#                                                    University  \
# First_Name
# Andrew                  Rutgers University School of Business
# Andrew                  Rutgers University School of Business
# Anett           Universidad Pedagógica "José Martí", Camagüey
# Angelico                                 Alaska Bible College
# Angie                                   Utsunomiya University
# ...                                                       ...
# Vincents        Universidad Nacional de La Libertad, Trujillo
# Virgil      Liaquat University of Medical & Health Science...
# Vivi                  National Law School of India University
# Viviyan                                    Universitas Kediri
# Vonnie                                       Walsh University
#
#                              Occupation    Salary  \
# First_Name
# Andrew              Curriculum Engineer   60000.0
# Andrew              Curriculum Engineer   60000.0
# Anett                     VP Accounting   81567.0
# Angelico             Nurse Practicioner   74347.0
# Angie                      Accountant I   65560.0
# ...                                 ...       ...
# Vincents               Dental Hygienist   99210.0
# Virgil              Marketing Assistant   75639.0
# Vivi                       Developer IV  118063.0
# Viviyan     Administrative Assistant II   83811.0
# Vonnie                 Graphic Designer   94380.0
#
#                                       Email  Age
# First_Name
# Andrew                 ayang@codedrills.com   53
# Andrew                 ayang@codedrills.com   53
# Anett                  adellit2d@smh.com.au   34
# Angelico              abenardetnq@hexun.com   48
# Angie                     amahareyrb@w3.org   61
# ...                                     ...  ...
# Vincents                 vainsleeqj@loc.gov   49
# Virgil                   vdunnetq@lycos.com   26
# Vivi                  vbrandi2g@harvard.edu   51
# Viviyan            vhalifax13@google.com.au   23
# Vonnie      vjindacek8t@cargocollective.com   28
#
# [894 rows x 9 columns]

# %% [markdown]
# ### 5. Select Rows with Conditionals using loc

# %%
# Select the rows where `Gender` is equal to 'Male' using `loc`.
people_csv.loc[people_csv["Gender"] == "Male"]
# Out:
#             Person_ID      Last_Name First_Name Gender  \
# First_Name
# Aaron             461       De Brett      Aaron   Male
# Abbot             459      McGaughey      Abbot   Male
# Abner             158  Christauffour      Abner   Male
# Ado               163        Behning        Ado   Male
# Ado               440        Raisher        Ado   Male
# ...               ...            ...        ...    ...
# Xymenes           848      Cotherill    Xymenes   Male
# Yankee            445          Kielt     Yankee   Male
# Zachariah         825           Akid  Zachariah   Male
# Zebulon            58      Josefovic    Zebulon   Male
# Zerk               59       Goulston       Zerk   Male
#
#                                                    University  \
# First_Name
# Aaron                                      Tsurumi University
# Abbot                                 University of Mauritius
# Abner                         Universidade Federal de Alagoas
# Ado                        Universidad José Cecilio del Valle
# Ado         Makhanlal Chaturvedi National University of Jo...
# ...                                                       ...
# Xymenes                         Universidad José Antonio Páez
# Yankee                                  Universidad del Azuay
# Zachariah                             Kyoto Sangyo University
# Zebulon                               Rajiv Gandhi University
# Zerk                    Universidad Tecnologica de la Mixteca
#
#                               Occupation    Salary  \
# First_Name
# Aaron                  Director of Sales   76098.0
# Abbot                       Food Chemist  105216.0
# Abner         Account Representative III  102758.0
# Ado                    Assistant Manager   64230.0
# Ado                   Speech Pathologist  113626.0
# ...                                  ...       ...
# Xymenes                        Professor  100907.0
# Yankee          Systems Administrator IV   90808.0
# Zachariah             Office Assistant I  111040.0
# Zebulon              Staff Accountant IV   82462.0
# Zerk        Budget/Accounting Analyst II   71428.0
#
#                                  Email  Age
# First_Name
# Aaron       adebrettcs@yellowpages.com   45
# Abbot            amcgaugheycq@jugem.jp   35
# Abner       achristauffour4d@tmall.com   47
# Ado                abehning4i@dmoz.org   42
# Ado                araisherc7@admin.ch   61
# ...                                ...  ...
# Xymenes         xcotherillnj@apple.com   30
# Yankee                ykieltcc@icio.us   44
# Zachariah             zakidmw@live.com   47
# Zebulon       zjosefovic1l@pcworld.com   63
# Zerk         zgoulston1m@artisteer.com   35
#
# [492 rows x 9 columns]

# %% [markdown]
# ### 6. Assign Values to Specific Rows and Columns Using Index Assignment with loc

# %%
# Change the `First_Name` value of the rows with 'Aaron' as the `First_Name` index to 'Arod'
people_csv.loc["Aaron", 'First_Name'] = "Arod"
people_csv
# Out:
#             Person_ID      Last_Name First_Name  Gender  \
# First_Name
# Aaron             461       De Brett       Arod    Male
# Abbot             459      McGaughey      Abbot    Male
# Abbye             125      MacKnight      Abbye  Female
# Abner             158  Christauffour      Abner    Male
# Abra              177         Vawton       Abra  Female
# ...               ...            ...        ...     ...
# Zachariah         825           Akid  Zachariah    Male
# Zandra            816     Kollaschek     Zandra  Female
# Zebulon            58      Josefovic    Zebulon    Male
# Zerk               59       Goulston       Zerk    Male
# Zsazsa             81        Cutajar     Zsazsa  Female
#
#                                                    University  \
# First_Name
# Aaron                                      Tsurumi University
# Abbot                                 University of Mauritius
# Abbye                               Savannah State University
# Abner                         Universidade Federal de Alagoas
# Abra                      Kawasaki University of Medical Care
# ...                                                       ...
# Zachariah                             Kyoto Sangyo University
# Zandra                       Western International University
# Zebulon                               Rajiv Gandhi University
# Zerk                    Universidad Tecnologica de la Mixteca
# Zsazsa      Asia Pacific Institute of Information Technolo...
#
#                               Occupation    Salary  \
# First_Name
# Aaron                  Director of Sales   76098.0
# Abbot                       Food Chemist  105216.0
# Abbye                Account Coordinator   90949.0
# Abner         Account Representative III  102758.0
# Abra                   Financial Advisor   76598.0
# ...                                  ...       ...
# Zachariah             Office Assistant I  111040.0
# Zandra          Senior Financial Analyst  109904.0
# Zebulon              Staff Accountant IV   82462.0
# Zerk        Budget/Accounting Analyst II   71428.0
# Zsazsa       Mechanical Systems Engineer   57814.0
#
#                                        Email  Age
# First_Name
# Aaron             adebrettcs@yellowpages.com   45
# Abbot                  amcgaugheycq@jugem.jp   35
# Abbye       amacknight3g@theglobeandmail.com   42
# Abner             achristauffour4d@tmall.com   47
# Abra                   avawton4w@nbcnews.com   23
# ...                                      ...  ...
# Zachariah                   zakidmw@live.com   47
# Zandra                 zkollaschekmn@home.pl   34
# Zebulon             zjosefovic1l@pcworld.com   63
# Zerk               zgoulston1m@artisteer.com   35
# Zsazsa                     zcutajar28@i2i.jp   27
#
# [973 rows x 9 columns]
