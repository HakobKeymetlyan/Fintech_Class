# %% [markdown]
# # Sorting Pandas DataFrames

# %% [markdown]
# ## 1. Import Libraries and Dependencies

# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## 2. Create a Path to the File Using Pathlib

# %%
# Use the Pathlib libary to set the path to the CSV
csv_path = Path('../Resources/cleaned_people_data.csv')

# %% [markdown]
# ## 3. Read the CSV into a Pandas DataFrame

# %%
# Read in the CSV as a DataFrame
people_df = pd.read_csv(csv_path)
people_df.head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0          1    Lenormand    Keriann  Female
# 1          2        Rupke    Huntley    Male
# 2          3  Dalgarnowch     Gorden    Male
# 3          4      Unnamed     Cullie    Male
# 4          5    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# 2  59196.0      gdalgarnowch2@microsoft.com   40
# 3  88493.0               cputten3@nymag.com   62
# 4  89073.0       astrangman4@bravesites.com   47

# %% [markdown]
# ## 4. Sort DataFrame in Ascending Order

# %%
# Sort ascending (default)
people_df.sort_values("First_Name")
# Out:
#      Person_ID      Last_Name First_Name  Gender  \
# 447        461       De Brett      Aaron    Male
# 445        459      McGaughey      Abbot    Male
# 122        125      MacKnight      Abbye  Female
# 153        158  Christauffour      Abner    Male
# 172        177         Vawton       Abra  Female
# ..         ...            ...        ...     ...
# 803        825           Akid  Zachariah    Male
# 794        816     Kollaschek     Zandra  Female
# 56          58      Josefovic    Zebulon    Male
# 57          59       Goulston       Zerk    Male
# 78          81        Cutajar     Zsazsa  Female
#
#                                             University  \
# 447                                 Tsurumi University
# 445                            University of Mauritius
# 122                          Savannah State University
# 153                    Universidade Federal de Alagoas
# 172                Kawasaki University of Medical Care
# ..                                                 ...
# 803                            Kyoto Sangyo University
# 794                   Western International University
# 56                             Rajiv Gandhi University
# 57               Universidad Tecnologica de la Mixteca
# 78   Asia Pacific Institute of Information Technolo...
#
#                        Occupation    Salary                             Email  \
# 447             Director of Sales   76098.0        adebrettcs@yellowpages.com
# 445                  Food Chemist  105216.0             amcgaugheycq@jugem.jp
# 122           Account Coordinator   90949.0  amacknight3g@theglobeandmail.com
# 153    Account Representative III  102758.0        achristauffour4d@tmall.com
# 172             Financial Advisor   76598.0             avawton4w@nbcnews.com
# ..                            ...       ...                               ...
# 803            Office Assistant I  111040.0                  zakidmw@live.com
# 794      Senior Financial Analyst  109904.0             zkollaschekmn@home.pl
# 56            Staff Accountant IV   82462.0          zjosefovic1l@pcworld.com
# 57   Budget/Accounting Analyst II   71428.0         zgoulston1m@artisteer.com
# 78    Mechanical Systems Engineer   57814.0                 zcutajar28@i2i.jp
#
#      Age
# 447   45
# 445   35
# 122   42
# 153   47
# 172   23
# ..   ...
# 803   47
# 794   34
# 56    63
# 57    35
# 78    27
#
# [973 rows x 9 columns]

# %% [markdown]
# ## 5. Sort DataFrame in Descending Order

# %%
# Sort descending
people_df.sort_values("First_Name", ascending=False)
# Out:
#      Person_ID      Last_Name First_Name  Gender  \
# 78          81        Cutajar     Zsazsa  Female
# 57          59       Goulston       Zerk    Male
# 56          58      Josefovic    Zebulon    Male
# 794        816     Kollaschek     Zandra  Female
# 803        825           Akid  Zachariah    Male
# ..         ...            ...        ...     ...
# 172        177         Vawton       Abra  Female
# 153        158  Christauffour      Abner    Male
# 122        125      MacKnight      Abbye  Female
# 445        459      McGaughey      Abbot    Male
# 447        461       De Brett      Aaron    Male
#
#                                             University  \
# 78   Asia Pacific Institute of Information Technolo...
# 57               Universidad Tecnologica de la Mixteca
# 56                             Rajiv Gandhi University
# 794                   Western International University
# 803                            Kyoto Sangyo University
# ..                                                 ...
# 172                Kawasaki University of Medical Care
# 153                    Universidade Federal de Alagoas
# 122                          Savannah State University
# 445                            University of Mauritius
# 447                                 Tsurumi University
#
#                        Occupation    Salary                             Email  \
# 78    Mechanical Systems Engineer   57814.0                 zcutajar28@i2i.jp
# 57   Budget/Accounting Analyst II   71428.0         zgoulston1m@artisteer.com
# 56            Staff Accountant IV   82462.0          zjosefovic1l@pcworld.com
# 794      Senior Financial Analyst  109904.0             zkollaschekmn@home.pl
# 803            Office Assistant I  111040.0                  zakidmw@live.com
# ..                            ...       ...                               ...
# 172             Financial Advisor   76598.0             avawton4w@nbcnews.com
# 153    Account Representative III  102758.0        achristauffour4d@tmall.com
# 122           Account Coordinator   90949.0  amacknight3g@theglobeandmail.com
# 445                  Food Chemist  105216.0             amcgaugheycq@jugem.jp
# 447             Director of Sales   76098.0        adebrettcs@yellowpages.com
#
#      Age
# 78    27
# 57    35
# 56    63
# 794   34
# 803   47
# ..   ...
# 172   23
# 153   47
# 122   42
# 445   35
# 447   45
#
# [973 rows x 9 columns]
