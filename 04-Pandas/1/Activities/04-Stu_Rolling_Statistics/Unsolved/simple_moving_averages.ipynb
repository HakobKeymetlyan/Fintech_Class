# %% [markdown]
# ### Instructor Demo: Simple Moving Averages
#
# This program reads in the CSV datasets of Netflix (NFLX) and plots the 20, 50, and 100 Simple Moving Averages (SMA) using the `rolling` function, `window` parameter, and `mean` function.

# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ### Read CSV in as DataFrame

# %%
# Set file path
nflx_data = Path("../Resources/nflx.csv")

# Read the CSV into a DataFrame and set the 'date' column as a datetime index
ntflx_df = pd.read_csv(nflx_data, index_col="date", infer_datetime_format=True, parse_dates=True)
ntflx_df.sort_index(inplace=True)

# Sort the data in forward chronological order, and display a few records
ntflx_df.head()
# Out:
#              close
# date
# 2009-05-18  5.5386
# 2009-05-19  5.6614
# 2009-05-20  5.7500
# 2009-05-21  5.5871
# 2009-05-22  5.5429

# %% [markdown]
# ### Plot Daily Closing Price of NFLX

# %%
# Plot DataFrame
ntflx_df.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Calculate 20-Day Simple Moving Average (SMA20)

# %%
# Calculate 20-day Simple Moving Average for NFLX Closing Prices
ntflx_sma_20 = ntflx_df.rolling(window=20).mean()
ntflx_sma_20
# Out:
#                close
# date
# 2009-05-18       NaN
# 2009-05-19       NaN
# 2009-05-20       NaN
# 2009-05-21       NaN
# 2009-05-22       NaN
# ...              ...
# 2019-05-10  368.6880
# 2019-05-13  368.3940
# 2019-05-14  368.2310
# 2019-05-15  368.0075
# 2019-05-16  368.2360
#
# [2517 rows x 1 columns]

# %% [markdown]
# ### Calculate 50-Day Simple Moving Average (SMA50)

# %%
# Calculate 50-day Simple Moving Average for NFLX Closing Prices
ntflx_sma_50 = ntflx_df.rolling(window=50).mean()
ntflx_sma_50
# Out:
#                close
# date
# 2009-05-18       NaN
# 2009-05-19       NaN
# 2009-05-20       NaN
# 2009-05-21       NaN
# 2009-05-22       NaN
# ...              ...
# 2019-05-10  364.3480
# 2019-05-13  364.1068
# 2019-05-14  363.9982
# 2019-05-15  364.0120
# 2019-05-16  364.0060
#
# [2517 rows x 1 columns]

# %% [markdown]
# ### Calculate 100-Day Simple Moving Average (SMA100)

# %%
# Calculate 100-day Simple Moving Average for NFLX Closing Prices
ntflx_sma_100 = ntflx_df.rolling(window=100).mean()
ntflx_sma_100
# Out:
#                 close
# date
# 2009-05-18        NaN
# 2009-05-19        NaN
# 2009-05-20        NaN
# 2009-05-21        NaN
# 2009-05-22        NaN
# ...               ...
# 2019-05-10  343.90385
# 2019-05-13  344.72845
# 2019-05-14  345.47515
# 2019-05-15  346.35735
# 2019-05-16  347.34465
#
# [2517 rows x 1 columns]

# %% [markdown]
# ### Overlay Daily Closing Prices of NFLX and SMAs

# %%
# Set figure of the daily closing prices of NFLX
ax = ntflx_df.plot(figsize=(25,10))

# Overlay SMA20, SMA50, and SMA100 on the same figure
ntflx_sma_20.plot(ax=ax)
ntflx_sma_50.plot(ax=ax)
ntflx_sma_100.plot(ax=ax)
# Set the legend of the figure
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Overlay Daily Closing Prices of NFLX and STDs

# %%
# Set figure of the daily closing prices of NFLX
ax = ntflx_df.plot(figsize=(25,10))

# Overlay STD20, STD50, and STD100 on the same figure
ntflx_df.rolling(window=20).std().plot(ax=ax)
ntflx_df.rolling(window=50).std().plot(ax=ax)
ntflx_df.rolling(window=100).std().plot(ax=ax)
# Set the legend of the figure
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Should Harold's firm invest long term in NFLX?
