# %% [markdown]
# ## Ice Breakers on Request

# %% [markdown]
# ### Import requests library

# %%
import requests

# %% [markdown]
# ### Declare `request_urls`

# %%
# Declare `url` variables
prog_joke_url = "http://api.worldbank.org/v2/country/all/indicator/NY.GDP.MKTP.CD?format=json"
rand_joke_url = "https://official-joke-api.appspot.com/jokes/random"
cat_facts_url = "https://cat-fact.herokuapp.com/facts"
dot_spending_url = "https://api.usaspending.gov//api/v2/references/agency/456/"
us_gdp_data_url = "http://api.worldbank.org/v2/country/us?format=json"

# %% [markdown]
# ### Execute `GET` request using `requests` library

# %%
# Execute `GET` request with url
response_data = requests.get(prog_joke_url)

# %% [markdown]
# ### Get response `status code`

# %%
# Print `response_data variable`
print(response_data)
# Out:
# <Response [200]>

# %% [markdown]
# ### Extract response `content`

# %%
# Store response using `content` attribute
response_content = response_data.content

response_content
# Out:
# b'[{"page":1,"pages":330,"per_page":50,"total":16492,"sourceid":"2","sourcename":"World Development Indicators","lastupdated":"2022-05-25"},[{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2021","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2020","value":920792331527.746,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2019","value":1009909855421.84,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2018","value":1012853224905.79,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2017","value":985355704660.083,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2016","value":873354876607.317,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2015","value":919930022724.422,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2014","value":984807065632.553,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2013","value":964242449960.242,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2012","value":950521438838.682,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2011","value":943378184761.64,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2010","value":847409491176.197,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2009","value":712557951490.059,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2008","value":708354291357.645,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2007","value":661242216575.303,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2006","value":575976209979.202,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2005","value":512259874365.035,"unit":"","obs_status":"","decimal":0},{"indicator": ...

# %% [markdown]
# ### Convert output to JSON

# %%
# Format data as JSON

data = response_data.json()

data
# Out:
# [{'page': 1,
#   'pages': 330,
#   'per_page': 50,
#   'total': 16492,
#   'sourceid': '2',
#   'sourcename': 'World Development Indicators',
#   'lastupdated': '2022-05-25'},
#  [{'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2021',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2020',
#    'value': 920792331527.746,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2019',
#    'value': 1009909855421.84,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2018',
#    'value': 1012853224905.79,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2017',
#    'value': 985355704660.083,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2016',
#    'value': 873354876607.317,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2015',
#    'value': 919930022724.422,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2014',
#    'value': 984807065632.553,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2013',
#    'value': 964242449960.242,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2012',
#    'value': 950521438838.682,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2011',
#    'value': 943378184761.64,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2010',
#    'value': 847409491176.197,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2009',
#    'value': 712557951490.059,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2008',
#    'value': 708354291357.645,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2007',
#    'value': 661242216575.303,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2006',
#    'value': 575976209979.202,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2005',
#    'value': 512259874365.035,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2004',
#    'value': 438875574172.163,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2003',
#    'value': 352692089583.594,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2002',
#    'value': 264895032411.725,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2001',
#    'value': 258843211433.203,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2000',
#    'value': 283952504751.698,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1999',
#    'value': 262197179765.274,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1998',
#    'value': 265837312146.489,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1997',
#    'value': 282212139032.667,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1996',
#    'value': 268439881940.973,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1995',
#    'value': 269666272048.118,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1994',
#    'value': 240163682396.831,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1993',
#    'value': 236549488096.632,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1992',
#    'value': 225540065318.55,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1991',
#    'value': 228438506210.276,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1990',
#    'value': 220794642844.207,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1989',
#    'value': 202293218094.809,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1988',
#    'value': 196533243686.932,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1987',
#    'value': 186900528876.037,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1986',
#    'value': 152882538715.827,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1985',
#    'value': 135635521184.351,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1984',
#    'value': 151840387979.238,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1983',
#    'value': 166123894835.005,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1982',
#    'value': 160833004562.906,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1981',
#    'value': 166769327812.192,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1980',
#    'value': 162749624521.557,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1979',
#    'value': 129459368084.579,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1978',
#    'value': 110583938872.362,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1977',
#    'value': 98774170464.0501,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1976',
#    'value': 86526285693.8376,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1975',
#    'value': 86760396610.3186,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1974',
#    'value': 81369112588.8632,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1973',
#    'value': 65493333397.4623,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1972',
#    'value': 50226254838.606,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0}]]

# %% [markdown]
# ### Format data with `json.dumps`

# %%
import json

# Use json.dumps to format data

print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "page": 1,
#         "pages": 330,
#         "per_page": 50,
#         "total": 16492,
#         "sourceid": "2",
#         "sourcename": "World Development Indicators",
#         "lastupdated": "2022-05-25"
#     },
#     [
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2021",
#             "value": null,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2020",
#             "value": 920792331527.746,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2019",
#             "value": 1009909855421.84,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2018",
#             "value": 1012853224905.79,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2017",
#             "value": 985355704660.083,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2016",
#             "value": 873354876607.317,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2015",
#             "value": 919930022724.422,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2014",
#             "value": 984807065632.553,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2013",
#             "value": 964242449960.242,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2012",
#             "value": 950521438838.682,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2011",
#             "value": 943378184761.64,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2010",
#             "value": 847409491176.197,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2009",
#             "value": 712557951490.059,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2008",
#             "value": 708354291357.645,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2007",
#             "value": 661242216575.303,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2006",
#             "value": 575976209979.202,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2005",
#             "value": 512259874365.035,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2004",
#             "value": 438875574172.163,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2003",
#             "value": 352692089583.594,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2002",
#             "value": 264895032411.725,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2001",
#             "value": 258843211433.203,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2000",
#             "value": 283952504751.698,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1999",
#             "value": 262197179765.274,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1998",
#             "value": 265837312146.489,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1997",
#             "value": 282212139032.667,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1996",
#             "value": 268439881940.973,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1995",
#             "value": 269666272048.118,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1994",
#             "value": 240163682396.831,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1993",
#             "value": 236549488096.632,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1992",
#             "value": 225540065318.55,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1991",
#             "value": 228438506210.276,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1990",
#             "value": 220794642844.207,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1989",
#             "value": 202293218094.809,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1988",
#             "value": 196533243686.932,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1987",
#             "value": 186900528876.037,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1986",
#             "value": 152882538715.827,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1985",
#             "value": 135635521184.351,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1984",
#             "value": 151840387979.238,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1983",
#             "value": 166123894835.005,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1982",
#             "value": 160833004562.906,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1981",
#             "value": 166769327812.192,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1980",
#             "value": 162749624521.557,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1979",
#             "value": 129459368084.579,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1978",
#             "value": 110583938872.362,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1977",
#             "value": 98774170464.0501,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1976",
#             "value": 86526285693.8376,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1975",
#             "value": 86760396610.3186,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1974",
#             "value": 81369112588.8632,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1973",
#             "value": 65493333397.4623,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1972",
#             "value": 50226254838.606,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         }
#     ]
# ]

# %% [markdown]
# ### Select value and store as variable

# %%
# Select a programming joke 


# Select a cat joke from JSON output
# selected_value = data['all'][0]['text']

# %%
# Print selected values
